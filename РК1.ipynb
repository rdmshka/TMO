# %% [markdown]
# # Рубежный контроль №1 по дисциплине "Технологии машинного обучения"
# ## Загидуллин Радмир, ИБМ3-65Б
# Вариант 6. датасет №6.
# Задание №1: Для заданного набора данных проведите корреляционный анализ. В случае наличия пропусков в данных удалите строки или колонки, содержащие пропуски. Сделайте выводы о возможности построения моделей машинного обучения и о возможном вкладе признаков в модель.

# %% [markdown]
# ### 1. Загрузка библиотек и основная информация о датасете

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %% [markdown]
# ### 2. Проверка датасета на пропуски

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# По результатам кода мы видим, что в нашем датасете отсутствуют пропуски.

# %% [markdown]
# ### 3. Корреляционный анализ датасета

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Гистограмма распределения GRE Score

# %%
plt.hist(df['GRE Score'])
plt.title('Распределение GRE Score')
plt.xlabel('GRE Score')
plt.ylabel('Количество студентов')
plt.show()

# %% [markdown]
# Гистограмма распределения GRE Score показывает, что большинство студентов имеют балл в диапазоне 310–325. Распределение близко к нормальному, что является благоприятным признаком для построения моделей машинного обучения.

# %% [markdown]
# ### 5. Выводы
# В ходе корреляционного анализа датасета Graduate Admissions было установлено следующее.
# Датасет содержит 500 записей и 9 признаков, пропуски в данных отсутствуют, что является благоприятным условием для построения моделей машинного обучения.
# Анализ корреляции признаков с целевой переменной Chance of Admit показал, что наибольший вклад в предсказание вероятности поступления вносят: CGPA (0.88), GRE Score (0.81) и TOEFL Score (0.79). Остальные признаки — University Rating, SOP, LOR и Research — также имеют положительную корреляцию с целевой переменной, однако в меньшей степени.
# Признак Serial No. является порядковым номером записи и не несёт смысловой нагрузки (корреляция ≈ 0), поэтому он должен быть исключён из набора признаков при построении модели.
# Таким образом, датасет пригоден для построения модели машинного обучения: данные полные, признаки имеют значимую корреляцию с целевой переменной, что свидетельствует о возможности построения качественной предсказательной модели.
